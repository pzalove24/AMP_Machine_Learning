# %%
from jki_python_bridge_for_labview import labview as lv
lv.connect()

# %%
array = lv.receive.image_array()
array
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 array = lv.receive.image_array()
#       2 array
#
# File <string>:4, in __call__(self)
#
# File c:\Users\p-rat\.virtualenvs\AMP_Machine_Learning--6wNdIZS\lib\site-packages\jki_python_bridge_for_labview\labview.py:231, in _Function._executeFunction(self, *args)
#     227         return _passCommand(self._name + '()')
#     229     else:
# --> 231         return _passCommand(self._name + '(' + repr(a) + ')')
#     233 else:
#     234     print(('Not Connected: Run "%s.connect()" method to connect.' % __name__))
#
# File c:\Users\p-rat\.virtualenvs\AMP_Machine_Learning--6wNdIZS\lib\site-packages\jki_python_bridge_for_labview\labview.py:128, in _passCommand(command)
#     125 _sockobj.sendall(
#     126     completeCommand)  # Note: sendall can only be used if the socket is in blocking mode (which is the default mode)
#     127 #    data = _sockobj.recv(11565536)
# --> 128 data = recv_all(_sockobj, 8)  # We expect the return msg to have an header with size information 8 char long
#     129 # python 3 requires data to be decoded
#     130 # if (pythonVersionMajor >= 3):
#     131 #     data = bytes.decode(data)
#     132 # search for an error in the response string
#     133 if data.rfind(_error_string) == 0:
#
# File c:\Users\p-rat\.virtualenvs\AMP_Machine_Learning--6wNdIZS\lib\site-packages\jki_python_bridge_for_labview\labview.py:85, in recv_all(my_socket, pack_size)
#      83 recv_size = 8192
#      84 while total_len < size:  # while we have not received all data
# ---> 85     sock_data = my_socket.recv(recv_size)  # Get recv_size amount of data
#      86     if not total_data:  # if total_data list is empty
#      87         if len(sock_data) > pack_size:  # if size of received data is greater than pack_size
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import ast
data = ast.literal_eval(array)

plt.imshow(data)
plt.show()

# %%
lv.disconnect()
